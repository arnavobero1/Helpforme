# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('groceries.csv')

# %%
dataset
# Out:
#              citrus fruit semi-finished bread         margarine  \
# 0          tropical fruit              yogurt            coffee
# 1              whole milk                 NaN               NaN
# 2               pip fruit              yogurt      cream cheese
# 3        other vegetables          whole milk    condensed milk
# 4              whole milk              butter            yogurt
# ...                   ...                 ...               ...
# 9829              sausage             chicken              beef
# 9830    cooking chocolate                 NaN               NaN
# 9831              chicken        citrus fruit  other vegetables
# 9832  semi-finished bread       bottled water              soda
# 9833              chicken      tropical fruit  other vegetables
#
#                    ready soups        Unnamed: 4      Unnamed: 5  \
# 0                          NaN               NaN             NaN
# 1                          NaN               NaN             NaN
# 2                 meat spreads               NaN             NaN
# 3     long life bakery product               NaN             NaN
# 4                         rice  abrasive cleaner             NaN
# ...                        ...               ...             ...
# 9829            hamburger meat      citrus fruit          grapes
# 9830                       NaN               NaN             NaN
# 9831                    butter            yogurt  frozen dessert
# 9832              bottled beer               NaN             NaN
# 9833                   vinegar     shopping bags             NaN
#
#            Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0                 NaN         NaN        NaN        NaN
# 1                 NaN         NaN        NaN        NaN
# 2                 NaN         NaN        NaN        NaN
# 3                 NaN         NaN        NaN        NaN
# 4                 NaN         NaN        NaN        NaN
# ...               ...         ...        ...        ...
# 9829  root vegetables  whole milk     butter        NaN
# 9830              NaN         NaN        NaN        NaN
# 9831    domestic eggs  rolls/buns        rum        NaN
# 9832              NaN         NaN        NaN        NaN
# 9833              NaN         NaN        NaN        NaN
#
# [9834 rows x 10 columns]

# %%
dataset1 = dataset.replace(np.nan, '', regex=True)

# %%
dataset1
# Out:
#              citrus fruit semi-finished bread         margarine  \
# 0          tropical fruit              yogurt            coffee
# 1              whole milk
# 2               pip fruit              yogurt      cream cheese
# 3        other vegetables          whole milk    condensed milk
# 4              whole milk              butter            yogurt
# ...                   ...                 ...               ...
# 9829              sausage             chicken              beef
# 9830    cooking chocolate
# 9831              chicken        citrus fruit  other vegetables
# 9832  semi-finished bread       bottled water              soda
# 9833              chicken      tropical fruit  other vegetables
#
#                    ready soups        Unnamed: 4      Unnamed: 5  \
# 0
# 1
# 2                 meat spreads
# 3     long life bakery product
# 4                         rice  abrasive cleaner
# ...                        ...               ...             ...
# 9829            hamburger meat      citrus fruit          grapes
# 9830
# 9831                    butter            yogurt  frozen dessert
# 9832              bottled beer
# 9833                   vinegar     shopping bags
#
#            Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0
# 1
# 2
# 3
# 4
# ...               ...         ...        ...        ...
# 9829  root vegetables  whole milk     butter
# 9830
# 9831    domestic eggs  rolls/buns        rum
# 9832
# 9833
#
# [9834 rows x 10 columns]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset1).transform(dataset1)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#                  -      4      5      6      7      8      9      :      U  \
# 0      True  False  False  False  False  False  False  False  False  False
# 1      True   True  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3      True  False  False  False  False  False  False  False  False  False
# 4      True  False   True  False  False  False  False  False   True   True
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9829  False  False  False  False  False  False  False  False  False  False
# 9830  False  False  False  False  False  False  False  False  False  False
# 9831  False  False  False  False  False  False  False  False  False  False
# 9832  False  False  False  False  False  False  False  False  False  False
# 9833  False  False  False  False  False  False  False  False  False  False
#
#       ...      i      m      n      o      p      r      s      t      u  \
# 0     ...   True  False  False  False  False   True   True   True   True
# 1     ...   True   True   True  False  False   True   True  False  False
# 2     ...   True   True   True  False  False   True  False  False  False
# 3     ...  False  False  False   True   True   True   True  False   True
# 4     ...  False   True   True  False  False  False  False  False  False
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9829  ...  False  False  False  False  False  False  False  False  False
# 9830  ...  False  False  False  False  False  False  False  False  False
# 9831  ...  False  False  False  False  False  False  False  False  False
# 9832  ...  False  False  False  False  False  False  False  False  False
# 9833  ...  False  False  False  False  False  False  False  False  False
#
#           y
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# ...     ...
# 9829  False
# 9830  False
# 9831  False
# 9832  False
# 9833  False
#
# [9834 rows x 28 columns]

# %%
from mlxtend.frequent_patterns import fpgrowth

fpgrowth(df, min_support=0.00001)
# Out:
#         support                          itemsets
# 0      0.000915                               (0)
# 1      0.000407                              (23)
# 2      0.000305                              (18)
# 3      0.000305                              (24)
# 4      0.000203                              (15)
# ...         ...                               ...
# 11154  0.000102      (0, 7, 8, 9, 10, 13, 14, 20)
# 11155  0.000102      (0, 7, 8, 9, 10, 14, 19, 20)
# 11156  0.000102     (0, 7, 8, 10, 13, 14, 19, 20)
# 11157  0.000102     (0, 7, 9, 10, 13, 14, 19, 20)
# 11158  0.000102  (0, 7, 8, 9, 10, 13, 14, 19, 20)
#
# [11159 rows x 2 columns]
